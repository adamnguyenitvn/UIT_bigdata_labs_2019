# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
import re

# %%
df = pd.read_csv('sales.csv')
df.head()
# Out:
#    order_id                       name           ordered_at  price  quantity  \
# 0     10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00  $3.50         3
# 1     10000   "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00  $3.50         1
# 2     10001         "SORBET" Raspberry  2018-01-01 12:14:54  $2.50         2
# 3     10001                        NaN  2018-01-01 12:14:54  $1.50         1
# 4     10001  "CONE" Dipped Waffle Cone  2018-01-01 12:14:54  $3.50         1
#
#   line_total
# 0     $10.50
# 1      $3.50
# 2      $5.00
# 3      $1.50
# 4      $3.50

# %%
df.shape
# Out:
# (29922, 6)

# %%
df.dtypes
# Out:
# order_id       int64
# name          object
# ordered_at    object
# price         object
# quantity       int64
# line_total    object
# dtype: object

# %%
df['ordered_at']=pd.to_datetime(df['ordered_at'])

# %%
df['price']=df['price'].str.replace('$','')
df['line_total']=df['line_total'].str.replace('$','')
df['price'] = pd.to_numeric(df['price'])
df['line_total'] = pd.to_numeric(df['line_total'])

# %%
df
# Out:
#        order_id                            name          ordered_at  price  \
# 0         10000        "ICE CREAM" Peanut Fudge 2018-01-01 11:30:00    3.5
# 1         10000        "ICE CREAM" Peanut Fudge 2018-01-01 11:30:00    3.5
# 2         10001              "SORBET" Raspberry 2018-01-01 12:14:54    2.5
# 3         10001                             NaN 2018-01-01 12:14:54    1.5
# 4         10001       "CONE" Dipped Waffle Cone 2018-01-01 12:14:54    3.5
# 5         10002                 "SORBET" Lychee 2018-01-01 12:23:09    3.0
# 6         10002                             NaN 2018-01-01 12:23:09    3.0
# 7         10002           "ICE CREAM" Earl Gray 2018-01-01 12:23:09    0.5
# 8         10003              "ICE CREAM" Matcha 2018-01-01 12:49:35    1.5
# 9         10004          "BEVERAGE" Iced Coffee 2018-01-01 13:22:59    2.5
# 10        10004             "BEVERAGE" Espresso 2018-01-01 13:22:59    2.5
# 11        10004           "ICE CREAM" Mint Chip 2018-01-01 13:22:59    1.5
# 12        10004             "CONE" Brownie Cone 2018-01-01 13:22:59    3.0
# 13        10004      "ICE CREAM" Dulce De Leche 2018-01-01 13:22:59    1.5
# 14        10005              "SORBET" Raspberry 2018-01-01 13:58:20    2.5
# 15        10005      "ICE CREAM" Dulce De Leche 2018-01-01 13:58:20    1.5
# 16        10005              "CONE" Waffle Cone 2018-01-01 13:58:20    4.0
# 17        10005       "ICE CREAM" Candied Bacon 2018-01-01 13:58:20    0.5
# 18        10005              "SORBET" Raspberry 2018-01-01 13:58:20    2.5
# 19        10006           "MISC" Ice Cream Cake 2018-01-01 14:55:50    2.0
# 20        10006                 "SORBET" Lychee 2018-01-01 14:55:50    3.0
# 21        10006              "CONE" Waffle Cone 2018-01-01 14:55:50    4.0
# 22        10006        "ICE CREAM" Peanut Fudge 2018-01-01 14:55:50    3.5
# 23        10006                  "SORBET" Lemon 2018-01-01 14:55:50    2.5
# 24        10007        "ICE CREAM" Peanut Fudge 2018-01-01 15:03:17    3.5
# 25        10007               "CONE" Sugar Cone 2018-01-01 15:03:17    1.0
# 26        10007              "SORBET" Raspberry 2018-01-01 15:03:17    2.5
# 19            3         6.0
# 20            1         3.0
# 21            1         4.0
# 22            2         7.0
# 23            3         7.5
# 24            3        10.5
# 25            3         3.0
# 26            2         5.0
# 27            1         2.5
# 28            2        -3.0
# 29            2         5.0
# ...         ...         ...
# 29892         2         4.0
# 29893         1         4.0
# 29894         3         7.5
# 29895         1         3.5
# 29896         2         2.0
# 29897         1         0.5
# 29898         2         3.0
# 29899         2         4.0
# 29900         2         5.0
# 29901         1         4.0
# 29902         3        10.5
# 29903         2         8.0
# 29904         1         1.5
# 29905         2         6.0
# 29906         1         2.0
# 29907         1         3.5
# 29908         1         2.0
# 29909         1         4.0
# 29910         1         1.5
# 29911         2         4.0
# 29912         3         7.5
# 29913         3         4.5
# 29914         3        12.0
# 29915         1         2.0
# 29916         3         7.5
# 29917         2        -3.0
# 29918         3        12.0
# 29919         3        10.5
# 29920         2         7.0
# 29921         2         1.0
#
# [29922 rows x 6 columns]

# %%
df[df.duplicated()].shape[0]
# Out:
# 538

# %%
df=df.drop_duplicates()

# %%
df.isnull().sum()
# Out:
# order_id         0
# name          1481
# ordered_at       0
# price            0
# quantity         0
# line_total       0
# dtype: int64

# %%
df[df['name'].isnull()].head()
# Out:
#     order_id name          ordered_at  price  quantity  line_total
# 3      10001  NaN 2018-01-01 12:14:54    1.5         1         1.5
# 6      10002  NaN 2018-01-01 12:23:09    3.0         3         9.0
# 27     10007  NaN 2018-01-01 15:03:17    2.5         1         2.5
# 77     10026  NaN 2018-01-02 03:25:40    0.5         2         1.0
# 88     10031  NaN 2018-01-02 05:45:48    3.5         3        10.5

# %%
df=df.dropna()

# %%
df[(df['price'] * df['quantity']) != df['line_total']].shape[0]
# Out:
# 28

# %%
df[df['line_total'] < 0].shape[0]
# Out:
# 279

# %%
df['line_total']= df['price'] * df['quantity']

# %%
df= df.drop (df[ df['line_total']<0].index)

# %%
df.describe()
# Out:
#            order_id         price      quantity    line_total
# count  27624.000000  27624.000000  27624.000000  27624.000000
# mean   14993.783051      2.511711      2.000724      5.028743
# std     2888.516649      1.059244      0.819432      3.085410
# min    10000.000000      0.500000      1.000000      0.500000
# 25%    12501.750000      1.500000      1.000000      2.500000
# 50%    14973.000000      2.500000      2.000000      4.500000
# 75%    17507.000000      3.500000      3.000000      7.500000
# max    19999.000000      4.000000      3.000000     12.000000

# %%
df['category'] = df['name'].str.partition('" ')[0]
df['name']= df['name'].str.partition('" ')[2]
df['category']=df['category'].str.replace('"','')
df
# Out:
#        order_id                name          ordered_at  price  quantity  \
# 0         10000        Peanut Fudge 2018-01-01 11:30:00    3.5         3
# 1         10000        Peanut Fudge 2018-01-01 11:30:00    3.5         1
# 2         10001           Raspberry 2018-01-01 12:14:54    2.5         2
# 4         10001  Dipped Waffle Cone 2018-01-01 12:14:54    3.5         1
# 5         10002              Lychee 2018-01-01 12:23:09    3.0         1
# 7         10002           Earl Gray 2018-01-01 12:23:09    0.5         3
# 8         10003              Matcha 2018-01-01 12:49:35    1.5         3
# 9         10004         Iced Coffee 2018-01-01 13:22:59    2.5         2
# 10        10004            Espresso 2018-01-01 13:22:59    2.5         1
# 29817     19997         Waffle Cone 2018-07-28 17:40:40    4.0         3
# 29818     19997        Blood Orange 2018-07-28 17:40:40    2.5         3
# 29819     19998              Lychee 2018-07-28 18:21:44    3.0         1
# 29820     19998          Rocky Road 2018-07-28 18:21:44    3.5         1
# 29821     19999        Blood Orange 2018-07-28 18:51:57    2.5         2
#
#        line_total   category
# 0            10.5  ICE CREAM
# 1             3.5  ICE CREAM
# 2             5.0     SORBET
# 4             3.5       CONE
# 5             3.0     SORBET
# 7             1.5  ICE CREAM
# 8             4.5  ICE CREAM
# 9             5.0   BEVERAGE
# 10            2.5   BEVERAGE
# 11            3.0  ICE CREAM
# 12            9.0       CONE
# 13            4.5  ICE CREAM
# 14            5.0     SORBET
# 15            3.0  ICE CREAM
# 16            8.0       CONE
# 17            0.5  ICE CREAM
# 18            2.5     SORBET
# 19            6.0       MISC
# 20            3.0     SORBET
# 21            4.0       CONE
# 22            7.0  ICE CREAM
# 23            7.5     SORBET
# 24           10.5  ICE CREAM
# 25            3.0       CONE
# 26            5.0     SORBET
# 29            5.0     SORBET
# 30            2.5     SORBET
# 31            1.0  ICE CREAM
# 32            7.5     SORBET
# 33            7.5     SORBET
# ...           ...        ...
# 29789         3.5  ICE CREAM
# 29790         7.0  ICE CREAM
# 29791         4.0       MISC
# 29792         8.0       CONE
# 29793        12.0       CONE
# 29794         1.5  ICE CREAM
# 29795         8.0       CONE
# 29796         1.5  ICE CREAM
# 29797         1.5  ICE CREAM
# 29798         2.5   BEVERAGE
# 29799        12.0       CONE
# 29800         3.5  ICE CREAM
# 29801         1.5  ICE CREAM
# 29803         3.5  ICE CREAM
# 29805         2.5     SORBET
# 29806         4.5  ICE CREAM
# 29807         7.0  ICE CREAM
# 29808         0.5  ICE CREAM
# 29810         1.5  ICE CREAM
# 29811         5.0     SORBET
# 29812         7.5   BEVERAGE
# 29813        10.5       CONE
# 29814         3.5  ICE CREAM
# 29815         4.0       MISC
# 29816         7.0  ICE CREAM
# 29817        12.0       CONE
# 29818         7.5     SORBET
# 29819         3.0     SORBET
# 29820         3.5  ICE CREAM
# 29821         5.0     SORBET
#
# [27624 rows x 7 columns]

# %%
df.dtypes
# Out:
# order_id               int64
# name                  object
# ordered_at    datetime64[ns]
# price                float64
# quantity               int64
# line_total           float64
# category              object
# dtype: object

# %%
df.head()
# Out:
#    order_id                name          ordered_at  price  quantity  \
# 0     10000        Peanut Fudge 2018-01-01 11:30:00    3.5         3
# 1     10000        Peanut Fudge 2018-01-01 11:30:00    3.5         1
# 2     10001           Raspberry 2018-01-01 12:14:54    2.5         2
# 4     10001  Dipped Waffle Cone 2018-01-01 12:14:54    3.5         1
# 5     10002              Lychee 2018-01-01 12:23:09    3.0         1
#
#    line_total   category
# 0        10.5  ICE CREAM
# 1         3.5  ICE CREAM
# 2         5.0     SORBET
# 4         3.5       CONE
# 5         3.0     SORBET

# %% [markdown]
# # Analysis, finally!

# %%
f, ax = plt.subplots(figsize=(10, 6))
df.groupby('name')['line_total'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
f.autofmt_xdate()
plt.show()
