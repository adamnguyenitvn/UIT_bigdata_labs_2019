# %% [markdown]
# ## 2. Sentiment Analysis
# In this exercise, we will classify the sentiment of text documents. Complete the code with TODO tag.
#
# References and Further Readings:
# + http://www.nltk.org/howto/sentiment.html
# + https://www.nltk.org/api/nltk.sentiment.html
# + http://datameetsmedia.com/vader-sentiment-analysis-explained/
# + https://github.com/cjhutto/vaderSentiment
# + https://marcobonzanini.com/2015/05/17/mining-twitter-data-with-python-part-6-sentiment-analysis-basics/
# + https://github.com/marrrcin/ml-twitter-sentiment-analysis
#
#
# ### 2.1. Classification approach
#
# Classification approach looks at previously labeled data in order to determine the sentiment of never-before-seen sentences. It involves training a model using previously seen text to predict/classify the sentiment of some new input text. The nice thing is that, with a greater volume of data, we generally get better prediction or classification results. However, unlike the lexical approach, we need previously labeled data.

# %%
from nltk.classify import NaiveBayesClassifier
# nltk.download('subjectivity')
nltk.download('movie_reviews')
from nltk.corpus import subjectivity
from nltk.corpus import movie_reviews
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *

# n_instances = 100
# subj_docs = [(sent, 'subj') for sent in subjectivity.sents(categories='subj')[:n_instances]]
# obj_docs = [(sent, 'obj') for sent in subjectivity.sents(categories='obj')[:n_instances]]
# len(subj_docs), len(obj_docs)

n_instances = None
if n_instances is not None:
    n_instances = int(n_instances/2)

pos_docs = [(list(movie_reviews.words(pos_id)), 'pos') for pos_id in movie_reviews.fileids('pos')[:n_instances]]
neg_docs = [(list(movie_reviews.words(neg_id)), 'neg') for neg_id in movie_reviews.fileids('neg')[:n_instances]]
len(pos_docs), len(neg_docs)
# Out:
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     /Users/tnguyen/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# (1000, 1000)

# %% [markdown]
# Each document is represented by a tuple (sentence, label). The sentence is tokenized, so it is represented by a list of strings:

# %%
pos_docs[0]
# Out:
# (['films',
#   'adapted',
#   'from',
#   'comic',
#   'books',
#   'have',
#   'had',
#   'plenty',
#   'of',
#   'success',
#   ',',
#   'whether',
#   'they',
#   "'",
#   're',
#   'about',
#   'superheroes',
#   '(',
#   'batman',
#   ',',
#   'superman',
#   ',',
#   'spawn',
#   ')',
#   ',',
#   'or',
#   'geared',
#   'toward',
#   'kids',
#   '(',
#   'casper',
#   ')',
#   'or',
#   'the',
#   'arthouse',
#   'crowd',
#   '(',
#   'ghost',
#   'world',
#   ')',
#   ',',
#   'but',
#   'there',
#   "'",
#   's',
#   'never',
#   'really',
#   'been',
#   'a',
#   'comic',
#   'book',
#   'like',
#   'from',
#   'hell',
#   'before',
#   '.',
#   'for',
#   'starters',
#   ',',
#   'it',
#   'was',
#   'created',
#   'by',
#   'alan',
#   'moore',
#   '(',
#   'and',
#   'eddie',
#   'campbell',
#   ')',
#   ',',
#   'who',
#   'brought',
#   'the',
#   'medium',
#   'to',
#   'a',
#   'whole',
#   'new',
#   'level',
#   'in',
#   'the',
#   'mid',
#   "'",
#   '80s',
#   'with',
#   'a',
#   '12',
#   '-',
#   'part',
#   'series',
#   'called',
#   'the',
#   'watchmen',
#   '.',
#   'to',
#   'say',
#   'moore',
#   'and',
#   'campbell',
#   'thoroughly',
#   'researched',
#   'the',
#   'subject',
#   'of',
#   'jack',
#   'the',
#   'ripper',
#   'would',
#   'be',
#   'like',
#   'saying',
#   'michael',
#   'jackson',
#   'is',
#   'starting',
#   'to',
#   'look',
#   'a',
#   'little',
#   'odd',
#   '.',
#   'the',
#   'book',
#   '(',
#   'or',
#   '"',
#   'graphic',
#   'novel',
#   ',',
#   '"',
#   'if',
#   'you',
#   'will',
#   ')',
#   'is',
#   'over',
#   '500',
#   'pages',
#   'long',
#   'and',
#   'includes',
#   'nearly',
#   '30',
#   'more',
#   'that',
#   'consist',
#   'of',
#   'nothing',
#   'but',
#   'footnotes',
#   '.',
#   'in',
#   'other',
#   'words',
#   ',',
#   'don',
#   "'",
#   't',
#   'dismiss',
#   'this',
#   'film',
#   'because',
#   'of',
#   'its',
#   'source',
#   '.',
#   'if',
#   'you',
#   'can',
#   'get',
#   'past',
#   'the',
#   'whole',
#   'comic',
#   'book',
#   'thing',
#   ',',
#   'you',
#   'might',
#   'find',
#   'another',
#   'stumbling',
#   'block',
#   'in',
#   'from',
#   'hell',
#   "'",
#   's',
#   'directors',
#   ',',
#   'albert',
#   'and',
#   'allen',
#   'hughes',
#   '.',
#   'getting',
#   'the',
#   'hughes',
#   'brothers',
#   'to',
#   'direct',
#   'this',
#   'seems',
#   'almost',
#   'as',
#   'ludicrous',
#   'as',
#   'casting',
#   'carrot',
#   'top',
#   'in',
#   ',',
#   'well',
#   ',',
#   'anything',
#   ',',
#   'but',
#   'riddle',
#   'me',
#   'this',
#   ':',
#   'who',
#   'better',
#   'to',
#   'direct',
#   'a',
#   'film',
#   'that',
#   "'",
#   's',
#   'set',
#   'in',
#   'the',
#   'ghetto',
#   'and',
#   'features',
#   'really',
#   'violent',
#   'street',
#   'crime',
#   'than',
#   'the',
#   'mad',
#   'geniuses',
#   'behind',
#   'menace',
#   'ii',
#   'society',
#   '?',
#   'the',
#   'ghetto',
#   'in',
#   'question',
#   'is',
#   ',',
#   'of',
#   'course',
#   ',',
#   'whitechapel',
#   'in',
#   '1888',
#   'london',
#   "'",
#   's',
#   'east',
#   'end',
#   '.',
#   'it',
#   "'",
#   's',
#   'a',
#   'filthy',
#   ',',
#   'sooty',
#   'place',
#   'where',
#   'the',
#   'whores',
#   '(',
#   'called',
#   '"',
#   'unfortunates',
#   '"',
#   ')',
#   'are',
#   'starting',
#   'to',
#   'get',
#   'a',
#   'little',
#   'nervous',
#   'about',
#   'this',
#   'mysterious',
#   'psychopath',
#   'who',
#   'has',
#   'been',
#   'carving',
#   'through',
#   'their',
#   'profession',
#   'with',
#   'surgical',
#   'precision',
#   '.',
#   'when',
#   'the',
#   'first',
#   'stiff',
#   'turns',
#   'up',
#   ',',
#   'copper',
#   'peter',
#   'godley',
#   '(',
#   'robbie',
#   'coltrane',
#   ',',
#   'the',
#   'world',
#   'is',
#   'not',
#   'enough',
#   ')',
#   'calls',
#   'in',
#   'inspector',
#   'frederick',
#   'abberline',
#   '(',
#   'johnny',
#   'depp',
#   ',',
#   'blow',
#   ')',
#   'to',
#   'crack',
#   'the',
#   'case',
#   '.',
#   'abberline',
#   ',',
#   'a',
#   'widower',
#   ',',
#   'has',
#   'prophetic',
#   'dreams',
#   'he',
#   'unsuccessfully',
#   'tries',
#   'to',
#   'quell',
#   'with',
#   'copious',
#   'amounts',
#   'of',
#   'absinthe',
#   'and',
#   'opium',
#   '.',
#   'upon',
#   'arriving',
#   'in',
#   'whitechapel',
#   ',',
#   'he',
#   'befriends',
#   'an',
#   'unfortunate',
#   'named',
#   'mary',
#   'kelly',
#   '(',
#   'heather',
#   'graham',
#   ',',
#   'say',
#   'it',
#   'isn',
#   "'",
#   't',
#   'so',
#   ')',
#   'and',
#   'proceeds',
#   'to',
#   'investigate',
#   'the',
#   'horribly',
#   'gruesome',
#   'crimes',
#   'that',
#   'even',
#   'the',
#   'police',
#   'surgeon',
#   'can',
#   "'",
#   't',
#   'stomach',
#   '.',
#   'i',
#   'don',
#   "'",
#   't',
#   'think',
#   'anyone',
#   'needs',
#   'to',
#   'be',
#   'briefed',
#   'on',
#   'jack',
#   'the',
#   'ripper',
#   ',',
#   'so',
#   'i',
#   'won',
#   "'",
#   't',
#   'go',
#   'into',
#   'the',
#   'particulars',
#   'here',
#   ',',
#   'other',
#   'than',
#   'to',
#   'say',
#   'moore',
#   'and',
#   'campbell',
#   'have',
#   'a',
#   'unique',
#   'and',
#   'interesting',
#   'theory',
#   'about',
#   'both',
#   'the',
#   'identity',
#   'of',
#   'the',
#   'killer',
#   'and',
#   'the',
#   'reasons',
#   'he',
#   'chooses',
#   'to',
#   'slay',
#   '.',
#   'in',
#   'the',
#   'comic',
#   ',',
#   'they',
#   'don',
#   "'",
#   't',
#   'bother',
#   'cloaking',
#   'the',
#   'identity',
#   'of',
#   'the',
#   'ripper',
#   ',',
#   'but',
#   'screenwriters',
#   'terry',
#   'hayes',
#   '(',
#   'vertical',
#   'limit',
#   ')',
#   'and',
#   'rafael',
#   'yglesias',
#   '(',
#   'les',
#   'mis',
#   '?',
#   'rables',
#   ')',
#   'do',
#   'a',
#   'good',
#   'job',
#   'of',
#   'keeping',
#   'him',
#   'hidden',
#   'from',
#   'viewers',
#   'until',
#   'the',
#   'very',
#   'end',
#   '.',
#   'it',
#   "'",
#   's',
#   'funny',
#   'to',
#   'watch',
#   'the',
#   'locals',
#   'blindly',
#   'point',
#   'the',
#   'finger',
#   'of',
#   'blame',
#   'at',
#   'jews',
#   'and',
#   'indians',
#   'because',
#   ',',
#   'after',
#   'all',
#   ',',
#   'an',
#   'englishman',
#   'could',
#   'never',
#   'be',
#   'capable',
#   'of',
#   'committing',
#   'such',
#   'ghastly',
#   'acts',
#   '.',
#   'and',
#   'from',
#   'hell',
#   "'",
#   's',
#   'ending',
#   'had',
#   'me',
#   'whistling',
#   'the',
#   'stonecutters',
#   'song',
#   'from',
#   'the',
#   'simpsons',
#   'for',
#   'days',
#   '(',
#   '"',
#   'who',
#   'holds',
#   'back',
#   'the',
#   'electric',
#   'car',
#   '/',
#   'who',
#   'made',
#   'steve',
#   'guttenberg',
#   'a',
#   'star',
#   '?',
#   '"',
#   ')',
#   '.',
#   'don',
#   "'",
#   't',
#   'worry',
#   '-',
#   'it',
#   "'",
#   'll',
#   'all',
#   'make',
#   'sense',
#   'when',
#   'you',
#   'see',
#   'it',
#   '.',
#   'now',
#   'onto',
#   'from',
#   'hell',
#   "'",
#   's',
#   'appearance',
#   ':',
#   'it',
#   "'",
#   's',
#   'certainly',
#   'dark',
#   'and',
#   'bleak',
#   'enough',
#   ',',
#   'and',
#   'it',
#   "'",
#   's',
#   'surprising',
#   'to',
#   'see',
#   'how',
#   'much',
#   'more',
#   'it',
#   'looks',
#   'like',
#   'a',
#   'tim',
#   'burton',
#   'film',
#   'than',
#   'planet',
#   'of',
#   'the',
#   'apes',
#   'did',
#   '(',
#   'at',
#   'times',
#   ',',
#   'it',
#   'seems',
#   'like',
#   'sleepy',
#   'hollow',
#   '2',
#   ')',
#   '.',
#   'the',
#   'print',
#   'i',
#   'saw',
#   'wasn',
#   "'",
#   't',
#   'completely',
#   'finished',
#   '(',
#   'both',
#   'color',
#   'and',
#   'music',
#   'had',
#   'not',
#   'been',
#   'finalized',
#   ',',
#   'so',
#   'no',
#   'comments',
#   'about',
#   'marilyn',
#   'manson',
#   ')',
#   ',',
#   'but',
#   'cinematographer',
#   'peter',
#   'deming',
#   '(',
#   'don',
#   "'",
#   't',
#   'say',
#   'a',
#   'word',
#   ')',
#   'ably',
#   'captures',
#   'the',
#   'dreariness',
#   'of',
#   'victorian',
#   '-',
#   'era',
#   'london',
#   'and',
#   'helped',
#   'make',
#   'the',
#   'flashy',
#   'killing',
#   'scenes',
#   'remind',
#   'me',
#   'of',
#   'the',
#   'crazy',
#   'flashbacks',
#   'in',
#   'twin',
#   'peaks',
#   ',',
#   'even',
#   'though',
#   'the',
#   'violence',
#   'in',
#   'the',
#   'film',
#   'pales',
#   'in',
#   'comparison',
#   'to',
#   'that',
#   'in',
#   'the',
#   'black',
#   '-',
#   'and',
#   '-',
#   'white',
#   'comic',
#   '.',
#   'oscar',
#   'winner',
#   'martin',
#   'childs',
#   "'",
#   '(',
#   'shakespeare',
#   'in',
#   'love',
#   ')',
#   'production',
#   'design',
#   'turns',
#   'the',
#   'original',
#   'prague',
#   'surroundings',
#   'into',
#   'one',
#   'creepy',
#   'place',
#   '.',
#   'even',
#   'the',
#   'acting',
#   'in',
#   'from',
#   'hell',
#   'is',
#   'solid',
#   ',',
#   'with',
#   'the',
#   'dreamy',
#   'depp',
#   'turning',
#   'in',
#   'a',
#   'typically',
#   'strong',
#   'performance',
#   'and',
#   'deftly',
#   'handling',
#   'a',
#   'british',
#   'accent',
#   '.',
#   'ians',
#   'holm',
#   '(',
#   'joe',
#   'gould',
#   "'",
#   's',
#   'secret',
#   ')',
#   'and',
#   'richardson',
#   '(',
#   '102',
#   'dalmatians',
#   ')',
#   'log',
#   'in',
#   'great',
#   'supporting',
#   'roles',
#   ',',
#   'but',
#   'the',
#   'big',
#   'surprise',
#   'here',
#   'is',
#   'graham',
#   '.',
#   'i',
#   'cringed',
#   'the',
#   'first',
#   'time',
#   'she',
#   'opened',
#   'her',
#   'mouth',
#   ',',
#   'imagining',
#   'her',
#   'attempt',
#   'at',
#   'an',
#   'irish',
#   'accent',
#   ',',
#   'but',
#   'it',
#   'actually',
#   'wasn',
#   "'",
#   't',
#   'half',
#   'bad',
#   '.',
#   'the',
#   'film',
#   ',',
#   'however',
#   ',',
#   'is',
#   'all',
#   'good',
#   '.',
#   '2',
#   ':',
#   '00',
#   '-',
#   'r',
#   'for',
#   'strong',
#   'violence',
#   '/',
#   'gore',
#   ',',
#   'sexuality',
#   ',',
#   'language',
#   'and',
#   'drug',
#   'content'],
#  'pos')

# %% [markdown]
# We separately split subjective and objective instances to keep a balanced uniform class distribution in both train and test sets.

# %%
# TODO: split training and testing data as 80/20
train_pos_docs = ...
test_pos_docs = ...
train_neg_docs = ...
test_neg_docs = ...

# TODO: or split the training and testing sets randomly
train_pos_docs, test_pos_docs = ...
train_neg_docs, test_neg_docs = ...

training_docs = train_pos_docs+train_neg_docs
testing_docs = test_pos_docs+test_neg_docs
sentim_analyzer = SentimentAnalyzer()
all_words_neg = sentim_analyzer.all_words([mark_negation(doc) for doc in training_docs])

all_words_neg[:5]
# Out:
# ['films', 'adapted', 'from', 'comic', 'books']

# %% [markdown]
# We use simple unigram word features, handling negation:

# %%
unigram_feats = sentim_analyzer.unigram_word_feats(all_words_neg, min_freq=4)
print(len(unigram_feats))
sentim_analyzer.add_feat_extractor(extract_unigram_feats, unigrams=unigram_feats)
# Out:
# 2721

# %% [markdown]
# We apply features to obtain a feature-value representation of our datasets:

# %%
training_set = sentim_analyzer.apply_features(training_docs)
test_set = sentim_analyzer.apply_features(testing_docs)
print(training_set[0])
# Out:
# ({'contains(bronx)': False, 'contains(unfortunately)': False, 'contains(order)': False, 'contains(friday)': False, 'contains(currently)': False, 'contains(thus)': False, 'contains(henry)': False, 'contains(addiction)': False, 'contains(kid)': False, 'contains(few)': False, 'contains(detective)': False, 'contains(know_NEG)': False, 'contains(many)': False, 'contains(across)': False, 'contains(government)': False, 'contains(williams)': False, 'contains(jake)': False, 'contains(niro)': False, 'contains(,_NEG)': False, 'contains(bobby)': False, 'contains(hard)': False, 'contains(each)': False, 'contains(throughout)': False, 'contains(sudden)': False, 'contains(far)': False, 'contains(british)': True, 'contains(action_NEG)': False, 'contains(state)': False, 'contains(disappointment)': False, 'contains(minutes_NEG)': False, 'contains(how)': True, 'contains(song)': True, 'contains(succeeds)': False, 'contains(entertaining)': False, 'contains(with_NEG)': False, 'contains(beat)': False, 'contains(painful)': False, 'contains(million)': False, 'contains(a)': True, 'contains(matron)': False, 'contains(scenes_NEG)': False, 'contains(batman)': True, 'contains(was)': True, 'contains(s_NEG)': False, 'contains(guess)': False, 'contains(hanks)': False, 'contains(prison)': False, 'contains(to_NEG)': False, 'contains(merely)': False, 'contains(sure)': False, 'contains(dubbed)': False, 'contains(caulder)': False, 'contains(solid)': True, 'contains(chan)': False, 'contains(aren)': False, 'contains(number)': False, 'contains(screenwriter)': False, 'contains(tough)': False, 'contains(annoying)': False, 'contains(coming)': False, 'contains(seem)': False, 'contains(catherine)': False, 'contains(movie_NEG)': False, 'contains(talented)': False, 'contains(murphy)': False, 'contains(kitchen)': False, 'contains(noir)': False, 'contains(spoken)': False, 'contains(heat)': False, 'contains(alice)': False, 'contains(depth)': False, 'contains(greater)': False, 'contains(piece)': False, 'contains(core)': False, 'contains(grow)': False, 'contains(features)': True, 'contains(dies)': False, 'contains(she_NEG)': False, 'contains(ringwald)': False, 'contains(childhood)': False, 'contains(usually)': False, 'contains(cover)': False, 'contains(conspiracy)': False, 'contains(telling)': False, 'contains(call)': False, 'contains(behind)': True, 'contains(fails)': False, 'contains(going_NEG)': False, 'contains(twenty)': False, 'contains(truth)': False, 'contains(itself)': False, 'contains(element)': False, 'contains(off)': False, 'contains(students)': False, 'contains(tom)': False, 'contains(imagination)': False, 'contains(adequate)': False, 'contains(time_NEG)': False, 'contains(slowly)': False, 'contains(kaye)': False, 'contains(night)': False, 'contains(projects)': False, 'contains(powerful)': False, 'contains(stunt)': False, 'contains(critique)': False, 'contains(maybe)': False, 'contains(darth)': False, 'contains(behavior)': False, 'contains(fame)': False, 'contains(continues)': False, 'contains(rated)': False, 'contains(directed)': False, 'contains(cake)': False, 'contains(sort)': False, 'contains(form)': False, 'contains(basic)': False, 'contains(guy)': False, 'contains(base)': False, 'contains(featuring)': False, 'contains(packed)': False, 'contains(serial)': False, 'contains(around_NEG)': False, 'contains(families)': False, 'contains(twists)': False, 'contains(smart)': False, 'contains(most)': False, 'contains(1960)': False, 'contains(beautifully)': False, 'contains(cops)': False, 'contains(who_NEG)': False, 'contains(ba)': False, 'contains(if)': True, 'contains(have)': True, 'contains(silent)': False, 'contains(recurring)': False, 'contains(recent)': False, 'contains(sense)': True, 'contains(asked)': False, 'contains(thing_NEG)': False, 'contains(make_NEG)': False, 'contains(memorable)': False, 'contains(tell)': False, 'contains(amount)': False, 'contains(queen)': False, 'contains(two_NEG)': False, 'contains(otherwise)': False, 'contains(re_NEG)': False, 'contains( ...

# %% [markdown]
# We can now train our classifier on the training set, and subsequently output the evaluation results:

# %%
# TODO: Use Naive Bayes to train the sentiment classifier
# naive_bayes = NaiveBayesClassifier.train
# svm = SklearnClassifier(LinearSVC()).train
# maxent = MaxentClassifier.train
sentim_analyzer...
sentim_analyzer...
# Out:
# Training classifier
# Evaluating NaiveBayesClassifier results...
# {'Accuracy': 0.725,
#  'F-measure [neg]': 0.717948717948718,
#  'F-measure [pos]': 0.7317073170731707,
#  'Precision [neg]': 0.7368421052631579,
#  'Precision [pos]': 0.7142857142857143,
#  'Recall [neg]': 0.7,
#  'Recall [pos]': 0.75}

# %% [markdown]
# ### 2.2. Lexical approach
#
# Lexical approaches aim to map words to sentiment by building a lexicon or a 'dictionary of sentiment'. We can use this dictionary to assess the sentiment of phrases and sentences, without the need of looking at anything else. Sentiment can be categorical – such as {negative, neutral, positive} – or it can be numerical – like a range of intensities or scores. Lexical approaches look at the sentiment category or score of each word in the sentence and decide what the sentiment category or score of the whole sentence is. The power of lexical approaches lies in the fact that we do not need to train a model using labeled data, since we have everything we need to assess the sentiment of sentences in the dictionary of emotions. VADER is an example of a lexical method.

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %% [markdown]
# Run the lexical approach

# %%
sid = SentimentIntensityAnalyzer()
for doc in testing_docs:
    doc = " ".join(doc[0])
    print(doc[:100] + "...")
    ss = sid.polarity_scores(doc)
    for k in sorted(ss):
        print('{0}: {1}, '.format(k, ss[k]), end='')
    print()
# Out:
# just how inseparable is the team of sgt . martin riggs ( mel gibson ) and sgt . roger murtaugh ( dan...
# compound: 0.7656, neg: 0.103, neu: 0.791, pos: 0.106,
# since 1990 , the dramatic picture has undergone a certain change of style . now , instead of emphasi...
# compound: 0.9982, neg: 0.027, neu: 0.79, pos: 0.183,
# a big surprise to me . the good trailer had hinted that they pulled the impossible off , but making ...
# compound: 0.9779, neg: 0.145, neu: 0.65, pos: 0.205,
# after having heard so many critics describe " return to me " as an old - fashioned hollywood romance...
# compound: 0.9995, neg: 0.042, neu: 0.738, pos: 0.22,
# wild things is a suspenseful thriller starring matt dillon , denise richards , and neve campbell tha...
# compound: 0.9965, neg: 0.07, neu: 0.77, pos: 0.16,
# * * * * * * minor plot spoilers in review * * * * * * * * * * * * no major spoilers are in review * ...
# compound: 0.9904, neg: 0.073, neu: 0.82, pos: 0.107,
# are you tired of all the hot new releases being gone by the time you get to the video store ? waffle...
# compound: -0.9805, neg: 0.16, neu: 0.704, pos: 0.136,
# many people dislike french films for their lack of closure . while possibly shallow , i ' ve often h...
# compound: 0.9954, neg: 0.071, neu: 0.809, pos: 0.12,
# the keen wisdom of an elderly bank robber , the naive ambitions of a sexy hospital nurse , and a par...
# compound: 0.9496, neg: 0.119, neu: 0.737, pos: 0.144,
# robert benton has assembled a stellar , mature cast for his latest feature , twilight , a film noir ...
# compound: 0.9836, neg: 0.039, neu: 0.826, pos: 0.134,
# warning : anyone offended by blatant , leering machismo had better avoid this film . or lots of bloo...
# compound: -0.5806, neg: 0.128, neu: 0.764, pos: 0.108,
# accepting his oscar as producer of this year ' s best picture winner , saul zaentz remarked that his...
# compound: 0.9866, neg: 0.061, neu: 0.799, pos: 0.14,
# a bleak look at how the boston underworld operates , a film which was based on the best - seller by ...
# compound: -0.9903, neg: 0.152, neu: 0.743, pos: 0.106,
# " footloose " has only one goal in mind : to reel in an audience with cheesy sentiment and feel - go...
# compound: 0.9811, neg: 0.067, neu: 0.799, pos: 0.134,
# as i walked out of crouching tiger , hidden dragon i thought to myself that i had had just seen a gr...
# compound: 0.9956, neg: 0.088, neu: 0.73, pos: 0.182,
# " crazy / beautiful " suffers from the damned - if - you - do , damned - if - you - don ' t syndrome...
# compound: 0.7307, neg: 0.156, neu: 0.682, pos: 0.162,
# everyone knows someone like giles de ' ath : stuffy , arrogant , set in his ways , and at war with a...
# compound: 0.9984, neg: 0.088, neu: 0.723, pos: 0.189,
# for many people , procrastination isn ' t a problem to overcome , it ' s a high art . we ' ll do jus...
# compound: -0.9111, neg: 0.086, neu: 0.84, pos: 0.074,
# meet joe black ( reviewed on nov . 27 / 98 ) starring brad pitt , anthony hopkins , claire forlani i...
# compound: -0.9646, neg: 0.173, neu: 0.691, pos: 0.135,
# call it touched by a demon . gregory hoblit ' s fallen is a serial killer movie with an unusual , ho...
# compound: -0.98, neg: 0.139, neu: 0.742, pos: 0.119,
# before the remake of psycho appears , we ' ve got to suffer through this remake of an earlier hitchc...
# compound: -0.7119, neg: 0.152, neu: 0.701, pos: 0.147,
# coinciding with the emerging popularity of movies that deal with anything related to serial killers ...
# compound: -0.8438, neg: 0.173, neu: 0.653, pos: 0.173,
# edward burns tackles his third picture with no looking back , and like his previous two , it is a wo...
# compound: -0.9873, neg: 0.149, neu: 0.803, pos: 0.048,
# i don ' t expect much from eddie murphy these days . for the past four years , the gods of cinema --...
# compound: 0.916, neg: 0.121, neu: 0.737, pos: 0.141,
# brian de palma , the director who bought us carrie , dressed to kill and mission : impossible is bac...
# compound: -0.7203, neg: 0.127, neu: 0.755, pos: 0.118,
# it ' s now the anniversary of the slayings of julie james ' ( jennifer love hewitt ) best friends . ...
# compound: 0.976, neg: 0.101, neu: 0.751, pos: 0.148,
# lucas was wise to start his star wars trilogy with episode 4 : episode 1 is a boring , empty spectac...
# compound: -0.9552, neg: 0.118, neu: 0.802, pos: 0.081,
# five girls spend a day in a closed building doing inventory when a strange box gets delivered there ...
# compound: -0.9795, neg: 0.155, neu: 0.723, pos: 0.122,
# the first film produced by adam sandler ' s happy madison production company ( clever title eh ? ) i...
# compound: 0.9434, neg: 0.034, neu: 0.849, pos: 0.118,
# tectonic plates is an incredibly painful motion picture experience that nearly prompted me to walk o...
# compound: 0.9897, neg: 0.101, neu: 0.739, pos: 0.16,
# various films seen at the seattle film festival : it ' s all true / three men on a raft ( u . s . a ...
# compound: 0.999, neg: 0.083, neu: 0.747, pos: 0.17,
# capsule : the weakest and least engaging of the alien movies , dragged down by an uninvolving story ...
# compound: -0.982, neg: 0.159, neu: 0.742, pos: 0.099,
# " from the director of " the nightmare before christmas " it said in the previews , which i ' m gues...
# compound: 0.996, neg: 0.076, neu: 0.755, pos: 0.168,
# numerous comparisons can be made with this movie to past sci - fi , suspense thrillers . soldier is ...
# compound: 0.1613, neg: 0.06, neu: 0.873, pos: 0.067,
# a documentary from the twin hughes brothers , allen and albert ( dead presidents , menace ii society...
# compound: 0.993, neg: 0.08, neu: 0.782, pos: 0.138,
# gord brody ( tom green ) is an aspiring animator approaching thirty who still lives in parents jim (...
# compound: -0.7143, neg: 0.113, neu: 0.778, pos: 0.109,
# much ado about nothing . ah , how sweet the irony ! it ' s accepted wisdom in some circles - among e...
# compound: 0.9964, neg: 0.105, neu: 0.691, pos: 0.204,
# another formula ' feel good ' quirky comedy from the british isles , much like " waking ned devine ,...
# compound: 0.9876, neg: 0.109, neu: 0.744, pos: 0.147,
# " love to kill " starts off aimlessly and gets progressively less coherent as time passes . at the o...
# compound: -0.7196, neg: 0.146, neu: 0.721, pos: 0.133,
# whether you like the beatles or not , nobody wants to see the bee gee ' s take on some of the fab fo...
# compound: -0.9926, neg: 0.13, neu: 0.787, pos: 0.083,

# %% [markdown]
# ### 2.3 Comparing two approaches
#
# First we can transform the sentiment score by the lexical approach into label by the following rules:
#
# + positive sentiment: compound score > 0
# + negative sentiment: compound score <= 0

# %%
def lexical_sentiment(doc, sid=None):
    """TODO: return the label 'pos' or 'neg' for a document"""
    if sid is None: sid = SentimentIntensityAnalyzer()
    ...
    return label

for doc in testing_docs:
    doc = " ".join(doc[0])
    label = lexical_sentiment(doc, sid)
    print(doc[:100] + "...", label)
# Out:
# just how inseparable is the team of sgt . martin riggs ( mel gibson ) and sgt . roger murtaugh ( dan... pos
# since 1990 , the dramatic picture has undergone a certain change of style . now , instead of emphasi... pos
# a big surprise to me . the good trailer had hinted that they pulled the impossible off , but making ... pos
# after having heard so many critics describe " return to me " as an old - fashioned hollywood romance... pos
# wild things is a suspenseful thriller starring matt dillon , denise richards , and neve campbell tha... pos
# * * * * * * minor plot spoilers in review * * * * * * * * * * * * no major spoilers are in review * ... pos
# are you tired of all the hot new releases being gone by the time you get to the video store ? waffle... neg
# many people dislike french films for their lack of closure . while possibly shallow , i ' ve often h... pos
# the keen wisdom of an elderly bank robber , the naive ambitions of a sexy hospital nurse , and a par... pos
# robert benton has assembled a stellar , mature cast for his latest feature , twilight , a film noir ... pos
# warning : anyone offended by blatant , leering machismo had better avoid this film . or lots of bloo... neg
# accepting his oscar as producer of this year ' s best picture winner , saul zaentz remarked that his... pos
# a bleak look at how the boston underworld operates , a film which was based on the best - seller by ... neg
# " footloose " has only one goal in mind : to reel in an audience with cheesy sentiment and feel - go... pos
# as i walked out of crouching tiger , hidden dragon i thought to myself that i had had just seen a gr... pos
# " crazy / beautiful " suffers from the damned - if - you - do , damned - if - you - don ' t syndrome... pos
# everyone knows someone like giles de ' ath : stuffy , arrogant , set in his ways , and at war with a... pos
# for many people , procrastination isn ' t a problem to overcome , it ' s a high art . we ' ll do jus... neg
# meet joe black ( reviewed on nov . 27 / 98 ) starring brad pitt , anthony hopkins , claire forlani i... neg
# call it touched by a demon . gregory hoblit ' s fallen is a serial killer movie with an unusual , ho... neg
# before the remake of psycho appears , we ' ve got to suffer through this remake of an earlier hitchc... neg
# coinciding with the emerging popularity of movies that deal with anything related to serial killers ... neg
# edward burns tackles his third picture with no looking back , and like his previous two , it is a wo... neg
# i don ' t expect much from eddie murphy these days . for the past four years , the gods of cinema --... pos
# brian de palma , the director who bought us carrie , dressed to kill and mission : impossible is bac... neg
# it ' s now the anniversary of the slayings of julie james ' ( jennifer love hewitt ) best friends . ... pos
# lucas was wise to start his star wars trilogy with episode 4 : episode 1 is a boring , empty spectac... neg
# five girls spend a day in a closed building doing inventory when a strange box gets delivered there ... neg
# the first film produced by adam sandler ' s happy madison production company ( clever title eh ? ) i... pos
# tectonic plates is an incredibly painful motion picture experience that nearly prompted me to walk o... pos
# various films seen at the seattle film festival : it ' s all true / three men on a raft ( u . s . a ... pos
# capsule : the weakest and least engaging of the alien movies , dragged down by an uninvolving story ... neg
# " from the director of " the nightmare before christmas " it said in the previews , which i ' m gues... pos
# numerous comparisons can be made with this movie to past sci - fi , suspense thrillers . soldier is ... pos
# a documentary from the twin hughes brothers , allen and albert ( dead presidents , menace ii society... pos
# gord brody ( tom green ) is an aspiring animator approaching thirty who still lives in parents jim (... neg
# much ado about nothing . ah , how sweet the irony ! it ' s accepted wisdom in some circles - among e... pos
# another formula ' feel good ' quirky comedy from the british isles , much like " waking ned devine ,... pos
# " love to kill " starts off aimlessly and gets progressively less coherent as time passes . at the o... neg
# whether you like the beatles or not , nobody wants to see the bee gee ' s take on some of the fab fo... neg

# %% [markdown]
# Now we evaluate the lexical approach by computing accuracy metrics

# %%
from collections import defaultdict
from nltk.metrics import (accuracy as eval_accuracy, precision as eval_precision,
        recall as eval_recall, f_measure as eval_f_measure)

gold_results = defaultdict(set)
test_results = defaultdict(set)
acc_gold_results = []
acc_test_results = []
labels = set()
num = 0
for i, (text, label) in enumerate(testing_docs):
    labels.add(label)
    gold_results[label].add(i)
    acc_gold_results.append(label)
    observed = lexical_sentiment(" ".join(text), sid)
    num += 1
    acc_test_results.append(observed)
    test_results[observed].add(i)
metrics_results = {}

# TODO: compute the accuracy metrics
for label in labels:
    ...

for result in sorted(metrics_results):
        print('{0}: {1}'.format(result, metrics_results[result]))
# Out:
# Accuracy: 0.6
# F-measure [neg]: 0.5555555555555556
# F-measure [pos]: 0.6363636363636364
# Precision [neg]: 0.625
# Precision [pos]: 0.5833333333333334
# Recall [neg]: 0.5
# Recall [pos]: 0.7
